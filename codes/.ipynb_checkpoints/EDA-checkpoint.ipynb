# %% [markdown]
# # EDA
#
# Exploratory data analysis on the data.

# %% [markdown]
# Import libraries.

# %%
import pandas as pd
import time
import numpy as np
# from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
import scipy.stats as st
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# Use address and file name as follow.

# %%
path = '../datasets/'
file_name = 'train_sample.csv'

# %%
train_df = pd.read_csv(path+file_name, 
                       usecols=['ip','app','device',
                                'os', 'channel', 'click_time', 
                                'is_attributed'])

# %% [markdown]
# Check out the data head.

# %%
train_df.head()
# Out:
#        ip  app  device  os  channel           click_time  is_attributed
# 0   87540   12       1  13      497  2017-11-07 09:30:38              0
# 1  105560   25       1  17      259  2017-11-07 13:40:27              0
# 2  101424   12       1  19      212  2017-11-07 18:05:24              0
# 3   94584   13       1  13      477  2017-11-07 04:58:08              0
# 4   68413   12       1   1      178  2017-11-09 09:00:09              0

# %% [markdown]
# Convert the click time to day and hour and add it to data.

# %%
train_df['hour'] = pd.to_datetime(train_df.click_time).dt.hour.astype('uint8')
train_df['day'] = pd.to_datetime(train_df.click_time).dt.day.astype('uint8')

# %%
train_df.head()
# Out:
#        ip  app  device  os  channel           click_time  is_attributed  hour  \
# 0   87540   12       1  13      497  2017-11-07 09:30:38              0     9
# 1  105560   25       1  17      259  2017-11-07 13:40:27              0    13
# 2  101424   12       1  19      212  2017-11-07 18:05:24              0    18
# 3   94584   13       1  13      477  2017-11-07 04:58:08              0     4
# 4   68413   12       1   1      178  2017-11-09 09:00:09              0     9
#
#    day
# 0    7
# 1    7
# 2    7
# 3    7
# 4    9

# %% [markdown]
# Doing feathering, grouping-merging as follow.

# %%
gp = train_df[['ip','day','hour','channel']]\
    .groupby(by=['ip','day','hour'])[['channel']]\
    .count().reset_index()\
    .rename(index=str, columns={'channel': '*ip_day_hour_count_channel'})
train_df = train_df.merge(gp, on=['ip','day','hour'], how='left')


gp = train_df[['ip', 'app', 'channel']].groupby(by=['ip', 'app'])[['channel']].\
            count().reset_index().\
            rename(index=str, columns={'channel': '*ip_app_count_channel'})
train_df = train_df.merge(gp, on=['ip','app'], how='left')


gp = train_df[['ip','app', 'os', 'channel']].\
            groupby(by=['ip', 'app', 'os'])[['channel']].\
            count().reset_index().\
            rename(index=str, columns={'channel': '*ip_app_os_count_channel'})
train_df = train_df.merge(gp, on=['ip','app', 'os'], how='left')


gp = train_df[['ip','day','hour','channel']].\
            groupby(by=['ip','day','channel'])[['hour']].\
            var().reset_index().\
            rename(index=str, columns={'hour': '*ip_tchan_count'})
train_df = train_df.merge(gp, on=['ip','day','channel'], how='left')


gp = train_df[['ip','app', 'os', 'hour']].\
            groupby(by=['ip', 'app', 'os'])[['hour']].\
            var().reset_index().\
            rename(index=str, columns={'hour': '*ip_app_os_var'})
train_df = train_df.merge(gp, on=['ip','app', 'os'], how='left')


gp = train_df[['ip','app', 'channel', 'day']].\
            groupby(by=['ip', 'app', 'channel'])[['day']].\
            var().reset_index().\
            rename(index=str, columns={'day': '*ip_app_channel_var_day'})
train_df = train_df.merge(gp, on=['ip','app', 'channel'], how='left')

gp = train_df[['ip','app', 'channel','hour']].\
            groupby(by=['ip', 'app', 'channel'])[['hour']].\
            mean().reset_index().\
            rename(index=str, columns={'hour': '*ip_app_channel_mean_hour'})

train_df = train_df.merge(gp, on=['ip','app', 'channel'], how='left')

# %%
train_df.head()
# Out:
#        ip  app  device  os  channel           click_time  is_attributed  hour  \
# 0   87540   12       1  13      497  2017-11-07 09:30:38              0     9
# 1  105560   25       1  17      259  2017-11-07 13:40:27              0    13
# 2  101424   12       1  19      212  2017-11-07 18:05:24              0    18
# 3   94584   13       1  13      477  2017-11-07 04:58:08              0     4
# 4   68413   12       1   1      178  2017-11-09 09:00:09              0     9
#
#    day  *ip_day_hour_count_channel  *ip_app_count_channel  \
# 0    7                           1                      3
# 1    7                           4                      4
# 2    7                           1                      1
# 3    7                           1                      1
# 4    9                           1                      2
#
#    *ip_app_os_count_channel  *ip_tchan_count  *ip_app_os_var  \
# 0                         2              NaN            24.5
# ...

# %% [markdown]
# Check out the data info.

# %%
train_df.describe().T
# Out:
#                                count          mean           std  min  \
# ip                          100000.0  91255.879670  69835.553661  9.0
# app                         100000.0     12.047880     14.941500  1.0
# device                      100000.0     21.771250    259.667767  0.0
# os                          100000.0     22.818280     55.943136  0.0
# channel                     100000.0    268.832460    129.724248  3.0
# is_attributed               100000.0      0.002270      0.047591  0.0
# hour                        100000.0      9.328590      6.180586  0.0
# day                         100000.0      7.861460      0.889266  6.0
# *ip_day_hour_count_channel  100000.0      1.493280      2.020593  1.0
# *ip_app_count_channel       100000.0      3.580260     10.553764  1.0
# *ip_app_os_count_channel    100000.0      1.294880      1.644388  1.0
# *ip_tchan_count              10877.0     28.060797     33.822226  0.0
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
# ip                            100000 non-null int64
# app                           100000 non-null int64
# device                        100000 non-null int64
# os                            100000 non-null int64
# channel                       100000 non-null int64
# click_time                    100000 non-null object
# is_attributed                 100000 non-null int64
# hour                          100000 non-null uint8
# day                           100000 non-null uint8
# *ip_day_hour_count_channel    100000 non-null int64
# *ip_app_count_channel         100000 non-null int64
# *ip_app_os_count_channel      100000 non-null int64
# *ip_tchan_count               10877 non-null float64
# *ip_app_os_var                10285 non-null float64
# *ip_app_channel_var_day       15166 non-null float64
# *ip_app_channel_mean_hour     100000 non-null float64
# ...

# %% [markdown]
# Check out the uniques number for each column in data.

# %%
cols = train_df.columns
for col in cols:
    print('number of unique {}'.format(col), ' = ', len(train_df[col].unique()))
# Out:
# number of unique ip  =  34857
# number of unique app  =  161
# number of unique device  =  100
# number of unique os  =  130
# number of unique channel  =  161
# number of unique click_time  =  80350
# number of unique is_attributed  =  2
# number of unique hour  =  24
# number of unique day  =  4
# number of unique *ip_day_hour_count_channel  =  27
# number of unique *ip_app_count_channel  =  58
# number of unique *ip_app_os_count_channel  =  23
# number of unique *ip_tchan_count  =  629
# number of unique *ip_app_os_var  =  526
# number of unique *ip_app_channel_var_day  =  299
# number of unique *ip_app_channel_mean_hour  =  324

# %%
fig = px.parallel_categories(train_df, color="is_attributed", 
                             color_continuous_scale=px.colors.sequential.Inferno)
fig.show()

# %% [markdown]
# #### Some visualization on data.

# %%
cols = ['app','device','os', 
        'channel', 'hour', 'day',
        '*ip_day_hour_count_channel', '*ip_app_count_channel', 
        '*ip_app_os_count_channel', '*ip_app_channel_mean_hour', 
        'is_attributed']

colors = ['orange', 'red', 'blue', 
          'black', 'purple', 'skyblue',
          'orange', 'red', 'blue', 'black',
          'skyblue']

plt.figure(figsize=(15,14))


for counter, colnm in enumerate(cols,1):

    plt.subplot(4, 3, counter)
    plt.hist(train_df[colnm], bins = 20, 
             log=False, color = colors[counter-1])
    plt.xlabel(colnm)

    
path = '../Figures/'
file_name = 'All_distribution_plots_1.png'
plt.savefig(path+file_name)

# %% [markdown]
# As it is seen the data is very imbalanced.

# %%
print('Number of ones = ', (train_df['is_attributed'] != 0).sum())
print('Number of zeros = ', (train_df['is_attributed'] == 0).sum())
# Out:
# Number of ones =  227
# Number of zeros =  99773

# %% [markdown]
# #### Over sampling the data.

# %%
count_class_0 = (train_df['is_attributed'] == 0).sum()
count_class_1 = (train_df['is_attributed'] == 1).sum()

# %%
increas_num = (count_class_0 - count_class_1)

# %%
sub_attributed_mask = train_df["is_attributed"] == 1
sub_Not_attributed_mask = train_df["is_attributed"] == 0

# %%
df_train_1_over = train_df[sub_attributed_mask].sample(increas_num, replace=True)
train_df = pd.concat([df_train_1_over, train_df[sub_Not_attributed_mask]], axis=0)

# %%
print('Number of ones = ', (train_df['is_attributed'] != 0).sum())
print('Number of zeros = ', (train_df['is_attributed'] == 0).sum())
# Out:
# Number of ones =  99546
# Number of zeros =  99773

# %%
cols = ['app','device','os', 
        'channel', 'hour', 'day',
        '*ip_day_hour_count_channel', '*ip_app_count_channel', 
        '*ip_app_os_count_channel', '*ip_app_channel_mean_hour', 
        'is_attributed']

colors = ['orange', 'red', 'blue', 
          'black', 'purple', 'skyblue',
          'orange', 'red', 'blue', 'black',
          'skyblue']

plt.figure(figsize=(15,14))


for counter, colnm in enumerate(cols,1):

    plt.subplot(4, 3, counter)
    plt.hist(train_df[colnm], bins = 20, 
             log=False, color = colors[counter-1])
    plt.xlabel(colnm)

    
path = '../Figures/'
file_name = 'All_distribution_plots_oversampled.png'
plt.savefig(path+file_name)

# %% [markdown]
# ### Transfering
#
# Use transfer on the data to change the distributions. As is seen in the above plot, there are seven parameters that need to transform. I need to break their one column distribution and turn it to more bell-shaped distribution. Such distribution helps the ML algorithm to find the hidden patterns.

# %%
trans_colmns = ['app','device','os', 'day', 
                '*ip_day_hour_count_channel', 
                '*ip_app_count_channel', 
                '*ip_app_os_count_channel']

# %%
for col in trans_colmns:
    train_df[col] = train_df[col]**(1/20)

# %%
cols = ['app','device','os', 
        'channel', 'hour', 'day',
        '*ip_day_hour_count_channel', '*ip_app_count_channel', 
        '*ip_app_os_count_channel', '*ip_app_channel_mean_hour', 
        'is_attributed']

colors = ['orange', 'red', 'blue', 
          'black', 'purple', 'skyblue',
          'orange', 'red', 'blue', 'black',
          'skyblue']

plt.figure(figsize=(15,14))


for counter, colnm in enumerate(cols,1):

    plt.subplot(4, 3, counter)
    plt.hist(train_df[colnm], bins = 20, 
             log=False, color = colors[counter-1])
    plt.xlabel(colnm)

    
path = '../Figures/'
file_name = 'All_distribution_plots_oversampled_transfered.png'
plt.savefig(path+file_name)

# %% [markdown]
# #### Seaborn visualization
#
# See if there is a relation between different parameters

# %%
sns.set()

columns = ['app','device','os', 
           'channel', 'hour', 'day',
           '*ip_day_hour_count_channel', '*ip_app_count_channel', 
           '*ip_app_os_count_channel', '*ip_app_channel_mean_hour',
           'is_attributed']

sns.pairplot(train_df[columns],hue="is_attributed", 
                 palette="husl", markers=["o", "s"])


path = '../Figures/'
file_name = 'All_distribution_plots_2_sea.png'
plt.savefig(path+file_name)

# %% [markdown]
# Check out the distribution by device and app.

# %%
plt.figure(figsize=(15,5))


plt.subplot(1, 2, 1)
plt.hist([train_df[sub_attributed_mask]['app'], 
          train_df[sub_Not_attributed_mask]['app']],
          color=['goldenrod', 'grey'],
          bins=20, ec='k', density=True)
plt.title('Normalized Count distribution by attribute', fontsize=12)
plt.legend(['attributed', 'Not_attributed'])
plt.xlabel('app'); plt.ylabel('density')


plt.subplot(1, 2, 2)
plt.hist([train_df[sub_attributed_mask]['device'], 
          train_df[sub_Not_attributed_mask]['device']],
          color=['goldenrod', 'grey'],
          bins=20, ec='k', density=True)
plt.title('Normalized Count distribution by device', fontsize=12)
plt.legend(['attributed', 'Not_attributed'])
plt.xlabel('device'); plt.ylabel('density')


path = '../Figures/'
file_name = 'plots_3.png'
plt.savefig(path+file_name)

# %%
train_df_corr = train_df.corr()
train_df_corr
# Out:
#                                   ip       app    device        os   channel  \
# ip                          1.000000  0.010400 -0.001499 -0.000470  0.007563
# app                         0.010400  1.000000  0.248376  0.247160 -0.028238
# device                     -0.001499  0.248376  1.000000  0.924456 -0.035398
# os                         -0.000470  0.247160  0.924456  1.000000 -0.033175
# channel                     0.007563 -0.028238 -0.035398 -0.033175  1.000000
# is_attributed               0.054955  0.064426 -0.000695  0.006183 -0.023336
# hour                       -0.007955  0.026079  0.012035  0.014660 -0.021326
# day                         0.057067 -0.032182 -0.040110 -0.031336  0.000265
# *ip_day_hour_count_channel -0.136437  0.016673  0.012790  0.015869 -0.011584
# *ip_app_count_channel      -0.111683 -0.065259 -0.012810 -0.009107 -0.014575
# *ip_app_os_count_channel   -0.074923 -0.045549 -0.012343 -0.018260 -0.012439
# ...

# %%
plt.figure(figsize=(7,6))
sns.heatmap(train_df_corr[['is_attributed']].sort_values(by=['is_attributed'],ascending=False),
            vmin=-1,
            cmap='Dark2',
            annot=True);
path = '../Figures/'
file_name = 'EDA_corr_plot.png'
plt.savefig(path+file_name)
